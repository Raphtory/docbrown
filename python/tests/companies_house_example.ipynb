# %% [markdown]
# # Companies House Example 💼

# %% [markdown]
# Install and import all dependencies.

# %%
# %pip install requests
# %pip install pyvis
# Out:
# Requirement already satisfied: requests in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (2.28.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from requests) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from requests) (1.26.15)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyvis in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: networkx>=1.11 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from pyvis) (3.1)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from pyvis) (3.1.2)
# Requirement already satisfied: ipython>=5.3.0 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from pyvis) (8.12.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from pyvis) (3.0.1)
# Requirement already satisfied: pexpect>4.3 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: appnope in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (3.0.38)
# Requirement already satisfied: decorator in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: stack-data in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: backcall in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: traitlets>=5 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (5.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from jinja2>=2.9.6->pyvis) (2.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: pure-eval in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: six in /Users/pedrorico/.pyenv/versions/3.10.9/envs/raphtory/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visualise graph with vis.draw() method in Raphtory.
# ### vis.draw() requires a Raphtory graph.

# %% [markdown]
# 1. If you would like custom node images, you can add an image url as a property when adding a vertex onto the Raphtory graph. e.g. properties = {"image": "your-image-url.png"}. Then add the property name to variable `node_image` when calling vis.draw(). You will also need to set the variable `shape` as "image".
#
# 2. To change the thickness of an edge based off edge weight, make sure you add your edge weights as a property when adding edges to your Raphtory graph. e.g. properties = {"weight": 1}. You will also need to set the variable `edge_weight` to the your property name when calling vis.draw().
#
# 3. To add labels on your edges which can be seen when hovering over the edges with your cursor, you will need to add your label text as a property when adding your edges. You will also need to set the variable `edge_label` when you call vis.draw().

# %%
from raphtory import vis
from raphtory import Graph
import requests
from contextlib import closing
import csv
import codecs

url = "https://raw.githubusercontent.com/Raphtory/Data/main/companies_house_nhs_data.csv"
g = Graph()
with closing(requests.get(url, stream=True)) as r:
    reader = csv.reader(codecs.iterdecode(r.iter_lines(), 'utf-8'), delimiter=',')
    next(reader)
    for row in reader:
        src = row[1].strip()
        dst = row[7].strip()
        company = row[2].replace("'", "")
        notified_on = row[0]
        share = row[3]
        title = f'Ownership: {share}%, Notified On: {notified_on}'

        g.add_vertex(1, src, properties={"image": "https://www.seekpng.com/png/small/846-8465978_critres-de-choix-pour-la-solution-de-cration.png"})
        g.add_vertex(1, dst, properties={"image": "https://www.seekpng.com/png/small/846-8465978_critres-de-choix-pour-la-solution-de-cration.png"})
        g.add_vertex(1, company, properties={"image": "https://cdn-icons-png.flaticon.com/512/2083/2083417.png"})
        g.add_edge(1, src, company, properties={"title": title, "weight": share})
        g.add_edge(1, dst, company, properties={"title": title, "weight": share})

vis.to_networkx(graph=g, k=0.8, node_size=250, node_color="red")
vis.to_pyvis(graph=g, edge_color='#F6E1D3', edge_weight="weight", shape="image", edge_label="title", node_image="image")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# nx.html
